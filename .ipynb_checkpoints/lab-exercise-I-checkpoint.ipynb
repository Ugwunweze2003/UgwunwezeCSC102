# %% [markdown]
# # Ugwunweze Eze Chidiebube
#
# # Matric no: 20120612020
#
# # chidiebube.Ugwunweze@pau.edu.ng

# %%
# Exercise 2
a= 3
b= 3
c= 3

if a ==b and b ==c:
    print((a + b + c)*3)
else:
    print(a + b + c)
# Out:
# 27

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Exercise 3
a= 7
b= 2
if a == b:
    print("True")
elif a + b == 5:
    print("True")
elif a - b == 5:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Exercise 4
a= int(input("The value of a is "))
b= int(input("The value of b is "))
c= int(input("The value of c is "))
d= [a, b, c]
print ("The maximum value =",(max(d)))
print ("The minimum value =",(min(d))) 
print ("The middle value =",((a + b + c)-max(d)-min(d)))
# Out:
# The value of a is 8
# The value of b is 3
# The value of c is 7
# The maximum value = 8
# The minimum value = 3
# The middle value = 7

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Exercise 1
a= 22
b= 17
if a > b:
    print(((a - b))*2)
else: 
    print(abs(a-b))
# Out:
# 10

# %% [markdown]
# ![image.png](attachment:image.png)
